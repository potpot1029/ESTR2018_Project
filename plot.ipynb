# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from ipynb.fs.defs.markov_chain import generate_markov_chain

# %%
# read moves.csv file
moves_data = pd.read_csv('moves.csv', index_col=0)
moves_df = pd.DataFrame(moves_data)
display(moves_df)
# Out:
#     No of Moves  Probability
# 0           899     0.000001
# 1           901     0.000002
# 2           902     0.000007
# 3           903     0.000004
# 4           904     0.000009
# ..          ...          ...
# 73          973     0.000013
# 74          974     0.000006
# 75          975     0.000005
# 76          976     0.000005
# 77          979     0.000001
#
# [78 rows x 2 columns]

# %%
# display summary statistics of data
display(moves_data[["No of Moves"]].describe())
# Out:
#        No of Moves
# count    78.000000
# mean    938.512821
# std      22.728061
# min     899.000000
# 25%     919.250000
# 50%     938.500000
# 75%     957.750000
# max     979.000000

# %%
# plot bar chart for expected move
plt.bar(moves_df['No of Moves'], moves_df['Probability'])
plt.title('Number of moves to win')
plt.xlabel('Number of moves')
plt.ylabel('Probability')
# Out:
# Text(0, 0.5, 'Probability')

# %%
# read absorbing_states.csv file
absorbing_state_data = pd.read_csv('absorbing_states.csv', index_col=0)
absorbing_state_df = pd.DataFrame(absorbing_state_data)
display(absorbing_state_df)
# Out:
#            absorbing state  absorbing probability   sum
# 0       [2, 4, 4, 8, 2048]               0.035334  2066
# 1       [2, 2, 8, 8, 2048]               0.347396  2068
# 2       [4, 4, 4, 8, 2048]               0.003894  2068
# 3         [2, 2, 16, 2048]               0.003870  2068
# 4       [2, 4, 8, 8, 2048]               0.077021  2070
# 5         [2, 4, 16, 2048]               0.291512  2070
# 6       [4, 4, 8, 8, 2048]               0.004361  2072
# 7         [4, 4, 16, 2048]               0.032268  2072
# 8      [2, 2, 4, 16, 2048]               0.141260  2072
# 9      [2, 4, 4, 16, 2048]               0.039471  2074
# 10        [2, 8, 16, 2048]               0.012315  2074
# 11        [4, 8, 16, 2048]               0.001304  2076
# 12     [4, 4, 4, 16, 2048]               0.002636  2076
# 13     [2, 2, 8, 16, 2048]               0.005892  2076
# 14     [2, 4, 8, 16, 2048]               0.001348  2078
# 15     [4, 4, 8, 16, 2048]               0.000068  2080
# 16  [2, 2, 4, 8, 16, 2048]               0.000045  2080
# 17  [2, 4, 4, 8, 16, 2048]               0.000004  2082
# 18     [2, 8, 8, 16, 2048]               0.000001  2082
# 19     [4, 8, 8, 16, 2048]               0.000000  2084
# 20  [4, 4, 4, 8, 16, 2048]               0.000000  2084
# 21  [2, 2, 8, 8, 16, 2048]               0.000000  2084
# 22    [2, 2, 16, 16, 2048]               0.000000  2084
# 23  [2, 4, 8, 8, 16, 2048]               0.000000  2086
# 24    [2, 4, 16, 16, 2048]               0.000000  2086
# 25    [4, 4, 16, 16, 2048]               0.000000  2088

# %%
# plot absorbing probability (states)
sub_absorbing_state_df = absorbing_state_df[absorbing_state_df['absorbing probability'] != 0.0]

fig, ax = plt.subplots()
plt.bar(sub_absorbing_state_df['absorbing state'], sub_absorbing_state_df['absorbing probability'])
plt.title('Absorbing Probabilities')
plt.xlabel('Absorbing State')
plt.ylabel('Absorbing Probability')

plt.setp(ax.get_xticklabels(), fontsize=10, rotation='vertical')
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# plot absorbing probability (sum)
fig, ax = plt.subplots()
plt.bar(absorbing_state_df['sum'], absorbing_state_df['absorbing probability'])
plt.title('Absorbing Probabilities')
plt.xlabel('Sum of tile values')
plt.ylabel('Absorbing Probability')
plt.xlim([2065, 2080])

# plt.setp(ax.get_xticklabels(), fontsize=10, rotation='vertical')
# Out:
# (2065.0, 2080.0)
